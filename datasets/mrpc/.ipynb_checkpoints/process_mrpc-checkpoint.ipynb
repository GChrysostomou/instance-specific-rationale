# %%
# !wget -nc "https://download.microsoft.com/download/D/4/6/D46FF87A-F6B9-4252-AA8B-3604ED519838/MSRParaphraseCorpus.msi"
# !mkdir MRPC
# !cabextract MSRParaphraseCorpus.msi -d MRPC
# !cat MRPC/_2DEC3DBE877E4DB192D17C0256E90F1D | tr -d $'\r' > MRPC/msr_paraphrase_train.txt
# !cat MRPC/_D7B391F9EAFF4B1B8BCE8F21B20B1B61 | tr -d $'\r' > MRPC/msr_paraphrase_test.txt
# !rm MRPC/_*
# !rm MSRParaphraseCorpus.msi

## dev ids from glue

# !wget -nc 'https://firebasestorage.googleapis.com/v0/b/mtl-sentence-representations.appspot.com/o/data%2Fmrpc_dev_ids.tsv?alt=media&token=ec5c0836-31d5-48f4-b431-7480817f1adc' -P MRPC/
# Out:
# --2020-10-23 10:07:55--  https://download.microsoft.com/download/D/4/6/D46FF87A-F6B9-4252-AA8B-3604ED519838/MSRParaphraseCorpus.msi
# Resolving download.microsoft.com (download.microsoft.com)... 184.26.148.129, 2a02:26f0:c800:28d::e59, 2a02:26f0:c800:29a::e59
# Connecting to download.microsoft.com (download.microsoft.com)|184.26.148.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1359872 (1.3M) [application/octet-stream]
# Saving to: ‘MSRParaphraseCorpus.msi’
#
# MSRParaphraseCorpus 100%[===================>]   1.30M  --.-KB/s    in 0.08s
#
# 2020-10-23 10:07:55 (17.1 MB/s) - ‘MSRParaphraseCorpus.msi’ saved [1359872/1359872]
#
# mkdir: cannot create directory ‘MRPC’: File exists
# Extracting cabinet: MSRParaphraseCorpus.msi
#   extracting MRPC/_2D65ED66D69C42A28B021C3E24C1D8C0
#   extracting MRPC/_2DEC3DBE877E4DB192D17C0256E90F1D
#   extracting MRPC/_63DE49D9E7214609BE7E38DD145D8081
#   extracting MRPC/_B3CFEFE1C368459BA1D1B8A2FA07A16D
#   extracting MRPC/_C5BC91AAB1554DF3AF5E4105DE57C85A
#   extracting MRPC/_D18B15DC041F43D7925309EFFCFE0236
#   extracting MRPC/_D7B391F9EAFF4B1B8BCE8F21B20B1B61
#
# All done, no errors.
# --2020-10-23 10:07:56--  https://firebasestorage.googleapis.com/v0/b/mtl-sentence-representations.appspot.com/o/data%2Fmrpc_dev_ids.tsv?alt=media&token=ec5c0836-31d5-48f4-b431-7480817f1adc
# Resolving firebasestorage.googleapis.com (firebasestorage.googleapis.com)... 216.58.211.170, 2a00:1450:4009:81c::200a
# Connecting to firebasestorage.googleapis.com (firebasestorage.googleapis.com)|216.58.211.170|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6222 (6.1K) [text/tab-separated-values]
# Saving to: ‘MRPC/data%2Fmrpc_dev_ids.tsv?alt=media&token=ec5c0836-31d5-48f4-b431-7480817f1adc’
#
# data%2Fmrpc_dev_ids 100%[===================>]   6.08K  --.-KB/s    in 0s
#
# 2020-10-23 10:07:57 (21.9 MB/s) - ‘MRPC/data%2Fmrpc_dev_ids.tsv?alt=media&token=ec5c0836-31d5-48f4-b431-7480817f1adc’ saved [6222/6222]

# %%
import pandas as pd


def get_as_csv(path_to_data):
    all_data = []

    with open(path_to_data, "r", encoding = 'utf-8-sig') as f:

        for _id, line in enumerate(f):

            if _id == 0:

                headers = line.split("\t")
            
            else:
                
                line = line.split("\t")

                all_data.append({
                    headers[0] : line[0],
                    headers[1] : line[1],
                    headers[2] : line[2],
                    headers[3] : line[3],
                    headers[4] : line[4]    
                })
            
    return pd.DataFrame(all_data)

# %%
train = get_as_csv("MRPC/msr_paraphrase_train.txt")
test = get_as_csv("MRPC/msr_paraphrase_test.txt")

# %%
def retrieve_dev(path_to_ids, train_pd):
    
    train_pd["id_pairs"] = train_pd.apply(lambda x: x["#1 ID"] + "_" + x["#2 ID"], axis = 1)
    
    ids_list = []
    
    with open(path_to_ids, "r", encoding = 'utf-8-sig') as f:
        
        for _id, line in enumerate(f):
            
            line = line.split("\t")
            
            id_1 = line[0]
            id_2 = line[1].strip()
            
            ids_list.append(id_1 + "_" + id_2)
            
    dev_pd = train_pd[train_pd.id_pairs.isin(ids_list)]
    train_new = train_pd[~train_pd.id_pairs.isin(ids_list)]
    
    assert len(train_new) + len(dev_pd) == len(train_pd)
    
    return train_new, dev_pd
    
train, dev = retrieve_dev("MRPC/data%2Fmrpc_dev_ids.tsv?alt=media&token=ec5c0836-31d5-48f4-b431-7480817f1adc", train)

# %%
def process_for_pipeline(df, exp_split):
    
    label_pairs = {"0":"semantic equivalence", "1":"paraphrase"}
    
    if "id_pairs" not in df.columns:
        
        df["id_pairs"] = df.apply(lambda x: x["#1 ID"] + "_" + x["#2 ID"], axis = 1)
    
    df = df.rename(columns = {
        "#1 ID" : "doc_id",
        "id_pairs" : "annotation_id",
        "#1 String" : "document",
        "#2 String\n" : "query",
        "Quality" : "label"
    })
    
    df = df.drop(columns = "#2 ID")
    df["label_id"] = df.label.apply(lambda x : label_pairs[x])
    df["exp_split"] = exp_split

    return df

train = process_for_pipeline(train, "train")
dev = process_for_pipeline(dev, "dev")
test = process_for_pipeline(test, "test")
# Out:
# Index(['doc_id', 'document', 'query', 'label', 'annotation_id'], dtype='object')
#        doc_id                                           document  \
# 0      702876  Amrozi accused his brother, whom he called "th...
# 1     2108705  Yucaipa owned Dominick's before selling the ch...
# 2     1330381  They had published an advertisement on the Int...
# 3     3344667  Around 0335 GMT, Tab shares were up 19 cents, ...
# 4     1236820  The stock rose 2.11, or about 11 percent, to c...
# 5      738533  Revenue in the first quarter of the year dropp...
# 6      264589  The Nasdaq had a weekly gain of 17.27, or 1.2 ...
# 7      579975  The DVD-CCA then appealed to the state Supreme...
# 8     3114205  That compared with 35.18 million, or 24 cents ...
# 10     222621  Shares of Genentech, a much larger company wit...
# 11    3131772  Legislation making it harder for consumers to ...
# 12      58747  The Nasdaq composite index increased 10.73, or...
# 13    1464126  But he added group performance would improve i...
# 5     With the scandal hanging over Stewart's compan...     1
# 6     The tech-laced Nasdaq Composite .IXIC rallied ...     0
# 7     The DVD CCA appealed that decision to the U.S....     1
# 8     Earnings were affected by a non-recurring 8 mi...     0
# 10    Shares of Xoma fell 16 percent in early trade,...     0
# 11    Legislation making it harder for consumers to ...     0
# 12    The Nasdaq Composite index, full of technology...     0
# 13    De Sole said in the results statement that gro...     1
# 14    "Saddam's daughters had British schools and ho...     1
# 15    The head of the local disaster unit, Gyorgy He...     0
# 16    Senior Vice President Eric Rudder, formerly he...     0
# 17    Internal chaos has allowed foreign companies t...     0
# 19    Sheena Young, a spokesman for Child, the natio...     1
# 20    "I think you'll see a lot of job growth in the...     0
# 21    Panther's redesigned Finder navigation tool pu...     1
# 22    Tropical storm warnings were in place Thursday...     1
# 23    Zuccarini was ordered held without bail Wednes...     1
# 24    A BMI between 18.5 and 24.9 is considered norm...     0
# 26    But six months ago, the two sides managed to s...     1
# 27    Simply put, shy invividuals tend to be more ti...     1
# 28    "I wanted to bring the most beautiful people i...     1
# 29    The S&P 500 index was up 1.26, or 0.1 percent,...     0
# 30    Currently living onboard the space station are...     0
# 31    Although a small city-state, Singapore is the ...     1
# 34    Sub-indexes measuring prices, new orders, inve...     1
# ...                                                 ...   ...
# 4044  The interview, which also focuses on Schwarzen...     1
# 4045  The board has appointed Trevor Fetter, who ret...     1
# 4046  Charlie Chan is off the case for the Fox Movie...     1
# 4047  Among them are conversations between police, f...     1
# 4048  Germans represent more than a quarter of all f...     0
# 4050  Mr. Muhammad, 42, and 18-year-old Lee Boyd Mal...     1
# 4051  Yesterday, Mr. Romanow said it was an affront ...     1
# 4052  "The anticipated global sales improvement in t...     1
# 4054  Assessment of current business conditions impr...     1
# 4055  U.S. Capitol Police Chief Terrance Gainer said...     1
# 4056  SCO said it terminated Sequent's contract due ...     1
# 4057  Investors kept in mind Tuesday's warning from ...     1
# 4058  Mr McDevitt has been granted control of three ...     0
# 4059  Rolfe said Linksys overtook Cisco Systems last...     0
# 4060  He has a very good reputation," RT Jones analy...     0
# 4061  The eliminations at Eddie Bauer come at all di...     1
# 4062  We are cautiously optimistic regarding some im...     1
# 4063  "It was one of the few times in my life when I...     1
# 4064  "Please, keep doing your homework," said Bavel...     1
# 4065  While Qureia is respected and has a history of...     1
# 4066  "We don't want to go to war with anybody . . ....     1
# 4067  "The message to the public is: If you are thin...     1
# 4068  Saturday, officials in California described Ge...     1
# 4069  The health department spokesperson added the d...     1
# 4070  The changed national ownership limit allows a ...     1
# 4071  Brando said that "somebody ought to put a bull...     1
# 4072  Martin served two thirds of a five-year senten...     0
# 4073  In a statement, the ECB said the outlook for p...     1
# 4074  MSNBC.com first reported the CIA request on Fr...     1
# 4075  The 30-year bond US30YT=RR grew 1-3/32 for a y...     0
#
#         annotation_id              label_id exp_split
# 0       702876_702977            paraphrase     train
# 1     2108705_2108831  semantic equivalence     train
# 2     1330381_1330521            paraphrase     train
# 3     3344667_3344648  semantic equivalence     train
# 4     1236820_1236712            paraphrase     train
# 5       738533_737951            paraphrase     train
# 6       264589_264502  semantic equivalence     train
# 7       579975_579810            paraphrase     train
# 8     3114205_3114194  semantic equivalence     train
# 10      222621_222514  semantic equivalence     train
# 11    3131772_3131625  semantic equivalence     train
# 12        58747_58516  semantic equivalence     train
# 13    1464126_1464107            paraphrase     train
# 14      771416_771467            paraphrase     train
# 15      142746_142671  semantic equivalence     train
# 16    1286053_1286069  semantic equivalence     train
# 17    1563874_1563853  semantic equivalence     train
# 19    2150265_2150184            paraphrase     train
# 20    2044342_2044457  semantic equivalence     train
# 21    1284150_1284173            paraphrase     train
# 22    3270389_3270327            paraphrase     train
# 23    2294059_2294112            paraphrase     train
# 24    1713015_1712982  semantic equivalence     train
# 26    1321918_1321644            paraphrase     train
# 27    1239046_1239031            paraphrase     train
# 28    2907515_2907224            paraphrase     train
# 29    2791650_2791604  semantic equivalence     train
# 30    2559762_2559517  semantic equivalence     train
# 31      105493_105432            paraphrase     train
# 34        14663_14617            paraphrase     train
# ...               ...                   ...       ...
# 4044  2228681_2228695            paraphrase     train
# 4045    487240_487102            paraphrase     train
# 4046  1469341_1469352            paraphrase     train
# 4047  3052786_3052810            paraphrase     train
# 4048  1607481_1607344  semantic equivalence     train
# 4050  3021663_3021933            paraphrase     train
# 4051  3058389_3058484            paraphrase     train
# 4052  1279583_1279615            paraphrase     train
# 4054  1571093_1571028            paraphrase     train
# 4055  2980386_2980142            paraphrase     train
# 4056  2063589_2063578            paraphrase     train
# 4057    487738_487702            paraphrase     train
# 4058  1850317_1850031  semantic equivalence     train
# 4059  1050636_1050722  semantic equivalence     train
# 4060    613592_613574  semantic equivalence     train
# 4061      62256_62268            paraphrase     train
# 4062    378653_378621            paraphrase     train
# 4063  1037500_1037399            paraphrase     train
# 4064    552386_552172            paraphrase     train
# 4065  2936214_2936069            paraphrase     train
# 4066  1633651_1633682            paraphrase     train
# 4067  3285516_3285301            paraphrase     train
# 4068  1628068_1628145            paraphrase     train
# 4069  2436811_2436865            paraphrase     train
# 4070    749248_749566            paraphrase     train
# 4071  1620264_1620507            paraphrase     train
# 4072  1848001_1848224  semantic equivalence     train
# 4073    747160_747144            paraphrase     train
# 4074  2539933_2539850            paraphrase     train
# 4075    453575_453448  semantic equivalence     train
#
# [3668 rows x 7 columns]

# %%
import os
os.makedirs('data', exist_ok=True)
train.to_csv("data/train.csv", index = False)
dev.to_csv("data/dev.csv", index = False)
test.to_csv("data/test.csv", index = False)
# Out:
# array(['2108705',
#        "Yucaipa owned Dominick's before selling the chain to Safeway in 1998 for 2.5 billion.",
#        '2108831',
#        "Yucaipa bought Dominick's in 1995 for 693 million and sold it to Safeway for 1.8 billion in 1998.\n",
#        '0', '2108705_2108831'], dtype=object)
